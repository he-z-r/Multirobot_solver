# %%
""" This script tries only using the TuLiP toolbox to solve a multirobot planning execution (MrPE) problem.
A predefined paths are given and a control policy is generated by this script
"""

# Import the packages that we need
from __future__ import print_function
import numpy as np
from tulip import spec
from tulip.transys import machines
from tulip import synth
import gr1_fragment

# %%
# Define the parameters & desired trajectories
num_robots = 1  # must be > 1
num_cells = 2
init = np.array([1])
dest = np.array([2])

# %%
# Define the env_vars based on the params % trajectories
env_vars = set()
env_vars_list = []
for r in range(1, num_robots + 1):
    env_vars_list.append([])
    for p in range(1, num_cells + 1):
        new_env_var = 's' + str(r) + 'a' + str(p)
        env_vars |= {new_env_var}
        env_vars_list[r - 1].append(new_env_var)

# %%
print(env_vars)
# Out:
# {'s1a1', 's1a2'}

# %%
print(env_vars_list)
# Out:
# [['s1a1', 's1a2']]

# %%
# Define the initial conditions
env_init = set()
for r in range(num_robots):
    env_init |= {env_vars_list[r][init[r] - 1]}

# %%
print(env_init)
# Out:
# {'s1a1'}

# %%
env_safe = set()
env_prog = set()
# Encode the constraint that each robot can only appear in one position
env_unique = set()
for r in range(1, num_robots + 1):
    for i in range(len(env_vars_list[r - 1])):
        new_env_unique = '( ' + env_vars_list[r - 1][i] + ' ) <-> ( '
        for j in range(len(env_vars_list[r - 1])):
            if j != i:
                new_env_unique += '!' + env_vars_list[r - 1][j] + ' && '
        new_env_unique = new_env_unique[:-3] + ')'
        env_unique |= {new_env_unique}
env_safe |= env_unique

# %%
print(env_unique)
# Out:
# {'( s1a1 ) <-> ( !s1a2 )', '( s1a2 ) <-> ( !s1a1 )'}

# %%
# Encode the transition system relations
# transition = np.array([[0, 2, 7, 5], [1, 3, 0, 0], [2, 4, 0, 6], [3, 0, 0, 8], [0, 0, 1, 0], [0, 0, 3, 0], [0, 0, 0, 1], [0, 0, 4, 0]])
transition = np.array([[0, 2, 0, 0], [1, 0, 0, 0]])
actions = ['up', 'down', 'left', 'right']
env_trans = set()
# env_trans |= {'( s1a1 ) -> ( stop1 || down1 )'}
# env_trans |= {'( s1a2 ) -> ( stop1 || up1 )'}
for i in range(1, num_cells + 1):
    for r in range(num_robots):
        for d in range(4):
            if transition[i - 1][d] > 0:
                env_trans |= {'( ' + env_vars_list[r][i - 1] + ' && ' + actions[d] + str(r + 1) + ' ) -> X( ' +
                            env_vars_list[r][i - 1] + ' || ' + env_vars_list[r][transition[i - 1][d] - 1] + ' )'}
                # env_trans |= {'( ' + env_vars_list[r][i - 1] + ' && ' + actions[d] + str(r + 1) + ' ) -> X( ' +
                            # env_vars_list[r][transition[i - 1][d] - 1] + ' )'}
            else:
                env_trans |= {'( ' + env_vars_list[r][i - 1] + ' ) -> ( !' + actions[d] + str(r + 1) + ' )'}
                # env_trans |= {'( ' + env_vars_list[r][i - 1] + ' && ' + actions[d] + str(r + 1) + ' ) -> X( ' +
                  #    env_vars_list[r][i - 1] + ' )'}
        env_trans |= {'( ' + env_vars_list[r][i - 1] + ' && ' + 'stop' + str(r + 1) + ' ) -> X( ' +
                      env_vars_list[r][i - 1] + ' )'}

env_safe |= env_trans

# %%
print(env_trans)
# Out:
# {'( s1a1 ) -> ( !left1 )', '( s1a1 && stop1 ) -> X( s1a1 )', '( s1a2 ) -> ( !down1 )', '( s1a2 ) -> ( !left1 )', '( s1a1 ) -> ( !right1 )', '( s1a2 && stop1 ) -> X( s1a2 )', '( s1a2 && up1 ) -> X( s1a2 || s1a1 )', '( s1a2 ) -> ( !right1 )', '( s1a1 ) -> ( !up1 )', '( s1a1 && down1 ) -> X( s1a1 || s1a2 )'}

# %%
print(len(env_trans))
# Out:
# 10

# %%
# Encode the constraint that every robot should stay after reaching its destination
env_dest_stop = set()
sys_dest = set()
for r in range(num_robots):
    env_dest_stop |= {'( ' + env_vars_list[r][dest[r] - 1] + ' ) -> X( ' + env_vars_list[r][dest[r] - 1] + ' )'}
    sys_dest |= {env_vars_list[r][dest[r] - 1]}
env_safe |= env_dest_stop

# %%
print(env_dest_stop)
# Out:
# {'( s1a2 ) -> X( s1a2 )'}

# %%
print(sys_dest)
# Out:
# {'s1a2'}

# %%
# Encode the constraint that each robot should either not go or eventually not in the current cell
env_go = set()
for r in range(1, num_robots + 1):
    for i in range(num_cells):
        if i != dest[r - 1] - 1:
            env_go |= {'( !' + env_vars_list[r - 1][i] + ' || ' + 'stop' + str(r) + ' )'}
# env_prog |= env_go

# %%
print(env_go)
# Out:
# {'( !s1a1 || stop1 )'}

# %%
# Define sys_vars
sys_vars = set()
for r in range(1, num_robots + 1):
    sys_vars |= {'stop' + str(r)}
    sys_vars |= {'left' + str(r)}
    sys_vars |= {'right' + str(r)}
    sys_vars |= {'up' + str(r)}
    sys_vars |= {'down' + str(r)}

# %%
print(sys_vars)
# Out:
# {'stop1', 'left1', 'down1', 'up1', 'right1'}

# %%
# Define initial command. Assume nothing.
sys_init = set()

sys_safe = set()
sys_prog = set()
sys_prog |= sys_dest
sys_safe |= env_dest_stop
# Encode the constraint that each time one action must be selected
env_act = set()
for r in range(1, num_robots + 1):
    env_act |= {'( left' + str(r) + ' ) <-> ( ' + '!right' + str(r) + ' && ' + '!up' + str(r) + ' && ' + '!down' +
                str(r) + ' && ' + '!stop' + str(r) + ' )'}
    env_act |= {'( right' + str(r) + ' ) <-> ( ' + '!left' + str(r) + ' && ' + '!up' + str(r) + ' && ' + '!down' +
                str(r) + ' && ' + '!stop' + str(r) + ' )'}
    env_act |= {'( up' + str(r) + ' ) <-> ( ' + '!right' + str(r) + ' && ' + '!left' + str(r) + ' && ' + '!down' +
                str(r) + ' && ' + '!stop' + str(r) + ' )'}
    env_act |= {'( down' + str(r) + ' ) <-> ( ' + '!right' + str(r) + ' && ' + '!up' + str(r) + ' && ' + '!left' +
                str(r) + ' && ' + '!stop' + str(r) + ' )'}
    env_act |= {'( stop' + str(r) + ' ) <-> ( ' + '!right' + str(r) + ' && ' + '!up' + str(r) + ' && ' + '!down' +
                str(r) + ' && ' + '!left' + str(r) + ' )'}
    
env_safe |= env_act
print(env_act)
# Out:
# {'( left1 ) <-> ( !right1 && !up1 && !down1 && !stop1 )', '( down1 ) <-> ( !right1 && !up1 && !left1 && !stop1 )', '( up1 ) <-> ( !right1 && !left1 && !down1 && !stop1 )', '( stop1 ) <-> ( !right1 && !up1 && !down1 && !left1 )', '( right1 ) <-> ( !left1 && !up1 && !down1 && !stop1 )'}

# %%
# Encode the constraint that if ending point is reached, not go. And if ending point is not reached, always exist some
# robot that goes
sys_stop = set()
new_sys_nonstop = '( '
for r in range(1, num_robots + 1):
    sys_stop |= {'( ' + env_vars_list[r - 1][dest[r - 1] - 1] + ' ) -> ( ' + 'stop' + str(r) + ' )'}
    new_sys_nonstop += '( !' + env_vars_list[r - 1][dest[r - 1] - 1] + ' ) || '
new_sys_nonstop = new_sys_nonstop[:-3] + ') -> ( '
for r in range(1, num_robots + 1):
    new_sys_nonstop += '!stop' + str(r) + ' || '
new_sys_nonstop = new_sys_nonstop[:-3] + ')'
sys_stop |= {new_sys_nonstop}
# sys_safe |= sys_stop

# %%
print(sys_stop)
# Out:
# {'( s1a2 ) -> ( stop1 )', '( ( !s1a2 ) ) -> ( !stop1 )'}

# %%
# Encode the collision avoidance constraints
# No need if only one robot
sys_collision = set()
for i in range(num_cells):
    new_sys_collision = '!( '
    for r in range(num_robots):
        new_sys_collision += env_vars_list[r][i] + ' && '
    new_sys_collision = new_sys_collision[:-3] + ')'
    sys_collision |= {new_sys_collision}
# sys_safe |= sys_collision

# %%
print(sys_collision)
# Out:
# {'!( s1a1 )', '!( s1a2 )'}

# %%
# Create a GR(1) specification
specs = spec.GRSpec(env_vars, sys_vars, env_init, sys_init,
                    env_safe, sys_safe, env_prog, sys_prog)
specs.qinit = '\A \E'  # Moore initial condition synthesized too
specs.moore = False
specs.plus_one = False

# %%
print(specs)
# Out:
# ((s1a1) && [](( s1a1 ) <-> ( !s1a2 )) && [](( s1a2 ) <-> ( !s1a1 )) && [](( s1a1 && stop1 ) -> X( s1a1 )) && [](( down1 ) <-> ( !right1 && !up1 && !left1 && !stop1 )) && [](( stop1 ) <-> ( !right1 && !up1 && !down1 && !left1 )) && [](( s1a2 && up1 ) -> X( s1a1 )) && [](( s1a1 && down1 ) -> X( s1a2 )) && [](( right1 ) <-> ( !left1 && !up1 && !down1 && !stop1 )) && [](( s1a2 && stop1 ) -> X( s1a2 )) && [](( s1a1 ) -> ( stop1 || down1 )) && [](( left1 ) <-> ( !right1 && !up1 && !down1 && !stop1 )) && [](( up1 ) <-> ( !right1 && !left1 && !down1 && !stop1 )) && [](( s1a2 ) -> ( stop1 || up1 ))) -> ([](( s1a2 ) -> X( s1a2 )) && []<>(s1a2))

# %%
print('Start synthesis')
ctrl = synth.synthesize(specs)
print('End synthesis')
assert ctrl is not None, 'unrealizable'
# Out:
# Start synthesis
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-242-268063db233c> in <module>
#       1 print('Start synthesis')
# ----> 2 ctrl = synth.synthesize(specs)
#       3 print('End synthesis')
#       4 assert ctrl is not None, 'unrealizable'
#
# ~/.local/lib/python3.6/site-packages/tulip/synth.py in synthesize(specs, env, sys, ignore_env_init, ignore_sys_init, rm_deadends, solver)
#    1109         ignore_env_init,
#    1110         ignore_sys_init)
# -> 1111     return _synthesize(specs, solver, rm_deadends)
#    1112
#    1113
#
# ~/.local/lib/python3.6/site-packages/tulip/synth.py in _synthesize(specs, solver, rm_deadends)
#    1137             'Available options are: {options}').format(
#    1138                 solver=solver, options=options))
# -> 1139     return _trim_strategy(strategy, specs, rm_deadends=rm_deadends)
#    1140
#    1141
#
# ~/.local/lib/python3.6/site-packages/tulip/synth.py in _trim_strategy(strategy, specs, rm_deadends)
#    1158             n=len(ctrl.states)))
#    1159     if rm_deadends:
# -> 1160         ctrl.remove_deadends()
#    1161     return ctrl
#    1162
#
# ~/.local/lib/python3.6/site-packages/tulip/transys/labeled_graphs.py in remove_deadends(self)
#    1118             self.states.remove_from(s)
#    1119         m = len(self)
# -> 1120         assert n == 0 or m > 0, 'removed all {n} nodes!'.format(n=n)
#    1121         assert n >= 0, 'added {n} nodes'.format(n=n)
#    1122         print('removed {r} nodes from '
#
# AssertionError: removed all 3 nodes!

# %%
machines.random_run(ctrl, N=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-215-4d69d0ca4e15> in <module>
# ----> 1 machines.random_run(ctrl, N=20)
#
# NameError: name 'ctrl' is not defined

# %%
print(len(env_unique))
# Out:
# 16
